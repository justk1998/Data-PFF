# %%
import pandas as pd
import numpy as np
import numpy.linalg as npl
import matplotlib.pyplot as plt
import requests

cases_global = pd.read_csv("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv")
deaths_global = pd.read_csv("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv")
recovered_global = pd.read_csv("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv")
t = np.arange(46)
#np.size(cases_global.values, 1) - 4

# %%
hubei = cases_global[cases_global['Province/State'] == 'Hubei']
china = cases_global[cases_global['Country/Region'] == 'China']
italy = cases_global[cases_global['Country/Region'] == 'Italy']
thailand = cases_global[cases_global['Country/Region'] == 'Thailand']
us = cases_global[cases_global['Country/Region'] == 'US']
spain = cases_global[cases_global['Country/Region'] == 'Spain']

china = china.sum(axis = 0)[4:]
italy = italy.sum(axis = 0)[52:]
thailand = thailand.sum(axis = 0)[68:]
us = us.sum(axis = 0)[62:]
spain = spain.sum(axis = 0)[57:]

chinaplot = china.values
italyplot = italy.values
thailandplot = thailand.values
usplot = us.values
spainplot = spain.values

# %%
plot_chi = plt.scatter(np.arange(np.size(chinaplot)), chinaplot, c='b')
plt.title("China")
# Out:
# Text(0.5, 1.0, 'China')

# %%
plot_ita = plt.scatter(np.arange(np.size(italyplot)), italyplot, c='g')
plt.title("Italy")
# Out:
# Text(0.5, 1.0, 'Italy')

# %%
plot_us = plt.scatter(np.arange(np.size(usplot)), usplot, c='r')
plt.title("United States")
# Out:
# Text(0.5, 1.0, 'United States')

# %%
plot_us = plt.scatter(np.arange(np.size(thailandplot)), thailandplot, c='b')
plt.title("Thailand")
# Out:
# Text(0.5, 1.0, 'Thailand')

# %%
plot_us = plt.scatter(np.arange(np.size(spainplot)), spainplot, c='g')
plt.title("Spain")
# Out:
# Text(0.5, 1.0, 'Spain')
